# %%
import argparse

import tensorflow as tf
import cv2
from imutils import paths

class MTCNN:

    def __init__(self, model_path, min_size=40, factor=0.709, thresholds=[0.6, 0.7, 0.7]):
        self.min_size = min_size
        self.factor = factor
        self.thresholds = thresholds

        graph = tf.Graph()
        with graph.as_default():
            with open(model_path, 'rb') as f:
                graph_def = tf.GraphDef.FromString(f.read())
                tf.import_graph_def(graph_def, name='')
        self.graph = graph
        config = tf.ConfigProto(
            allow_soft_placement=True,
            intra_op_parallelism_threads=4,
            inter_op_parallelism_threads=4)
        config.gpu_options.allow_growth = True
        self.sess = tf.Session(graph=graph, config=config)

    def detect(self, img):
        feeds = {
            self.graph.get_operation_by_name('input').outputs[0]: img,
            self.graph.get_operation_by_name('min_size').outputs[0]: self.min_size,
            self.graph.get_operation_by_name('thresholds').outputs[0]: self.thresholds,
            self.graph.get_operation_by_name('factor').outputs[0]: self.factor
        }
        fetches = [self.graph.get_operation_by_name('prob').outputs[0],
                  self.graph.get_operation_by_name('landmarks').outputs[0],
                  self.graph.get_operation_by_name('box').outputs[0]]
        prob, landmarks, box = self.sess.run(fetches, feeds)
        return box, prob, landmarks


def main():
    mtcnn = MTCNN('./mtcnn.pb')
#     img = cv2.imread(args.image)
    j = 0
    for i in imagePaths:
        j = j+1
        img = cv2.imread(i,1)
        bbox, scores, landmarks = mtcnn.detect(img)

        print('total box:', len(bbox))
        for box, pts in zip(bbox, landmarks):
            box = box.astype('int32')
            img = cv2.rectangle(img, (box[1], box[0]), (box[3], box[2]), (255, 0, 0), 3)

            pts = pts.astype('int32')
            for i in range(5):
                img = cv2.circle(img, (pts[i+5], pts[i]), 1, (0, 255, 0), 2)
        cv2.imwrite('./aug_op/rk'+str(j)+'.jpg', img)
        

if __name__ == '__main__':
#     parser = argparse.ArgumentParser(description='tensorflow mtcnn')
#     parser.add_argument('image', help='image path')
#     args = parser.parse_args()
    imagePaths = list(paths.list_images('/home/ravikiranb/homedir/images/test/Augmented_frontal/santosh/'))
    main()

# %%
import argparse

import tensorflow as tf
import cv2
from imutils import paths
import matplotlib.pyplot as  plt

class MTCNN:

    def __init__(self, model_path, min_size=40, factor=0.709, thresholds=[0.6,0.7,0.8]):
        self.min_size = min_size
        self.factor = factor
        self.thresholds = thresholds

        graph = tf.Graph()
        with graph.as_default():
            with open(model_path, 'rb') as f:
                graph_def = tf.GraphDef.FromString(f.read())
                tf.import_graph_def(graph_def, name='')
        self.graph = graph
        config = tf.ConfigProto(
            allow_soft_placement=True,
            intra_op_parallelism_threads=4,
            inter_op_parallelism_threads=4)
        config.gpu_options.allow_growth = True
        self.sess = tf.Session(graph=graph, config=config)

    def detect(self, img):
        feeds = {
            self.graph.get_operation_by_name('input').outputs[0]: img,
            self.graph.get_operation_by_name('min_size').outputs[0]: self.min_size,
            self.graph.get_operation_by_name('thresholds').outputs[0]: self.thresholds,
            self.graph.get_operation_by_name('factor').outputs[0]: self.factor
        }
        fetches = [self.graph.get_operation_by_name('prob').outputs[0],
                  self.graph.get_operation_by_name('landmarks').outputs[0],
                  self.graph.get_operation_by_name('box').outputs[0]]
        prob, landmarks, box = self.sess.run(fetches, feeds)
        return box, prob, landmarks


def main():
    mtcnn = MTCNN('./mtcnn.pb')
#     img = cv2.imread(args.image)
    j = 0
    for k in imagePaths:
        j = j+1
#         if j == 2:
#             break
        img = cv2.imread(k,1)
        img_h, img_w = img.shape[:2]
        img_a = img_h*img_w
        
        bbox, scores, landmarks = mtcnn.detect(img)

#         print(bbox)
#         print('__________________________________########boxes#######__________________________________')
#         print(scores)
#         print('__________________________________########scores#######__________________________________')
#         print(landmarks)
#         print('__________________________________########landmarks#######__________________________________')
        print('total box:', len(bbox))
        for box, pts in zip(bbox, landmarks):
            box = box.astype('int32')
            box_w = box[3] - box[1]
            box_h = box[2] - box[0]
            box_a = box_w*box_h
            
            percent = box_a*100/img_a
            if percent > 3.0:
                print('percentage of bounding box in total image : {:.2f}'.format(percent))
                img = cv2.rectangle(img, (box[1], box[0]), (box[3], box[2]), (0, 255, 0), 3)

                pts = pts.astype('int32')
                for i in range(5):
                    img = cv2.circle(img, (pts[i+5], pts[i]), 4, (0, 0, 255), 8)
        cv2.imwrite('./aug_op/sv'+str(j)+'.jpg', img)
#         plt.figure(figsize=(10,20))
#         imgplot = plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
#         plt.show()
        

if __name__ == '__main__':
#     parser = argparse.ArgumentParser(description='tensorflow mtcnn')
#     parser.add_argument('image', help='image path')
#     args = parser.parse_args()
    imagePaths = list(paths.list_images('/home/ravikiranb/homedir/images/test/Augmented_frontal/santosh/'))
    main()
# Out:
# total box: 1
# percentage of bounding box in total image : 15.34
# total box: 1
# percentage of bounding box in total image : 13.88
# total box: 1
# percentage of bounding box in total image : 14.53
# total box: 1
# percentage of bounding box in total image : 15.81
# total box: 1
# percentage of bounding box in total image : 12.28
# total box: 1
# percentage of bounding box in total image : 8.89
# total box: 1
# percentage of bounding box in total image : 14.32
# total box: 1
# percentage of bounding box in total image : 16.55
# total box: 1
# percentage of bounding box in total image : 14.22
# total box: 2
# percentage of bounding box in total image : 9.84
# total box: 1
# percentage of bounding box in total image : 10.68
# total box: 1
# percentage of bounding box in total image : 12.16
# total box: 1
# percentage of bounding box in total image : 13.23
# total box: 1
# percentage of bounding box in total image : 13.90
# total box: 1
# percentage of bounding box in total image : 16.26
# total box: 1
# percentage of bounding box in total image : 8.47
# total box: 1
# percentage of bounding box in total image : 13.38
# total box: 1
# percentage of bounding box in total image : 16.12
# total box: 1
# percentage of bounding box in total image : 18.20
# total box: 1
# percentage of bounding box in total image : 16.80
# total box: 1
# percentage of bounding box in total image : 15.88
# total box: 1
# percentage of bounding box in total image : 14.28
# total box: 1
# percentage of bounding box in total image : 17.89
# total box: 1
# percentage of bounding box in total image : 13.21
# total box: 1
# percentage of bounding box in total image : 11.15
# total box: 1
# percentage of bounding box in total image : 14.53
# total box: 2
# percentage of bounding box in total image : 13.20
# total box: 1
# percentage of bounding box in total image : 14.07
# total box: 1
# percentage of bounding box in total image : 7.83
# total box: 2
# percentage of bounding box in total image : 8.19
# total box: 2
# percentage of bounding box in total image : 10.26
# total box: 1
# percentage of bounding box in total image : 13.42
# total box: 1
# percentage of bounding box in total image : 10.28
# total box: 2
# percentage of bounding box in total image : 9.57
# total box: 2
# percentage of bounding box in total image : 16.44
# total box: 1
# percentage of bounding box in total image : 11.49
# total box: 1
# percentage of bounding box in total image : 15.75
# total box: 1
# percentage of bounding box in total image : 15.96
# total box: 1
# percentage of bounding box in total image : 18.28
# total box: 1
# percentage of bounding box in total image : 16.19
# total box: 2
# percentage of bounding box in total image : 8.83
# total box: 1
# percentage of bounding box in total image : 13.08
# total box: 1
# percentage of bounding box in total image : 15.70
# total box: 1
# percentage of bounding box in total image : 12.91
# total box: 1
# percentage of bounding box in total image : 12.95
# total box: 1
# percentage of bounding box in total image : 14.16
# total box: 1
# percentage of bounding box in total image : 13.05
# total box: 3
# percentage of bounding box in total image : 8.15
# total box: 1
# percentage of bounding box in total image : 11.01
# total box: 1
# percentage of bounding box in total image : 15.08
# total box: 1
# percentage of bounding box in total image : 12.19
# total box: 1
# percentage of bounding box in total image : 13.43
# total box: 2
# percentage of bounding box in total image : 14.80
# total box: 1
# percentage of bounding box in total image : 12.20
# total box: 2
# percentage of bounding box in total image : 11.85
# percentage of bounding box in total image : 5.86
# total box: 1
# percentage of bounding box in total image : 10.06
# total box: 1
# percentage of bounding box in total image : 9.94
# total box: 1
# percentage of bounding box in total image : 20.81
# total box: 1
# percentage of bounding box in total image : 16.78
# total box: 1
# percentage of bounding box in total image : 15.33
# total box: 1
# percentage of bounding box in total image : 11.85
# total box: 1
# percentage of bounding box in total image : 15.74
# total box: 1
# percentage of bounding box in total image : 12.16
# total box: 1
# percentage of bounding box in total image : 10.10
# total box: 1
# percentage of bounding box in total image : 9.87
# total box: 2
# percentage of bounding box in total image : 17.99
# total box: 1
# percentage of bounding box in total image : 12.13
# total box: 1
# percentage of bounding box in total image : 11.74
# total box: 1
# percentage of bounding box in total image : 14.99
# total box: 3
# percentage of bounding box in total image : 12.31
# total box: 1
# percentage of bounding box in total image : 12.03
# total box: 2
# percentage of bounding box in total image : 15.46
# total box: 1
# percentage of bounding box in total image : 12.54
# total box: 1
# percentage of bounding box in total image : 15.58
# total box: 1
# percentage of bounding box in total image : 12.74
# total box: 1
# percentage of bounding box in total image : 11.57
# total box: 1
# percentage of bounding box in total image : 16.94
# total box: 1
# percentage of bounding box in total image : 13.58
# total box: 2
# percentage of bounding box in total image : 12.21
# total box: 2
# percentage of bounding box in total image : 11.08
# total box: 1
# percentage of bounding box in total image : 14.27
# total box: 1
# percentage of bounding box in total image : 9.99
# total box: 1
# percentage of bounding box in total image : 11.34
# total box: 2
# percentage of bounding box in total image : 7.47
# total box: 1
# percentage of bounding box in total image : 12.96
# total box: 1
# percentage of bounding box in total image : 16.72
# total box: 1
# percentage of bounding box in total image : 15.17
# total box: 1
# percentage of bounding box in total image : 15.51
# total box: 1
# percentage of bounding box in total image : 18.62
# total box: 1
# percentage of bounding box in total image : 12.62
# total box: 1
# percentage of bounding box in total image : 11.18
# total box: 1
# percentage of bounding box in total image : 13.59
# total box: 1
# percentage of bounding box in total image : 14.98
# total box: 1
# percentage of bounding box in total image : 17.14
# total box: 2
# percentage of bounding box in total image : 11.77
# total box: 1
# percentage of bounding box in total image : 13.58
# total box: 1
# percentage of bounding box in total image : 10.07
# total box: 1
# percentage of bounding box in total image : 14.28
# total box: 1
# percentage of bounding box in total image : 8.78
# total box: 1
# percentage of bounding box in total image : 13.48
# total box: 1
# percentage of bounding box in total image : 14.87
# total box: 1
# percentage of bounding box in total image : 9.74
# total box: 2
# percentage of bounding box in total image : 12.55
# total box: 1
# percentage of bounding box in total image : 14.80
# total box: 1
# percentage of bounding box in total image : 13.57
# total box: 1
# percentage of bounding box in total image : 17.38
# total box: 1
# percentage of bounding box in total image : 13.54
# total box: 1
# percentage of bounding box in total image : 16.25
# total box: 1
# percentage of bounding box in total image : 12.16
# total box: 1
# percentage of bounding box in total image : 21.84
# total box: 1
# percentage of bounding box in total image : 16.20
# total box: 2
# percentage of bounding box in total image : 11.10
# total box: 2
# percentage of bounding box in total image : 8.47
# total box: 1
# percentage of bounding box in total image : 13.99
# total box: 2
# percentage of bounding box in total image : 17.57
# total box: 1
# percentage of bounding box in total image : 17.63
# total box: 1
# percentage of bounding box in total image : 15.76
# total box: 1
# percentage of bounding box in total image : 14.76
# total box: 1
# percentage of bounding box in total image : 10.75
# total box: 1
# percentage of bounding box in total image : 8.05
# total box: 4
# percentage of bounding box in total image : 14.23
# total box: 1
# percentage of bounding box in total image : 19.57
# total box: 2
# percentage of bounding box in total image : 15.32
# total box: 1
# percentage of bounding box in total image : 10.16
# total box: 1
# percentage of bounding box in total image : 15.52
# total box: 1
# percentage of bounding box in total image : 10.70
# total box: 1
# percentage of bounding box in total image : 16.34
# total box: 1
# percentage of bounding box in total image : 15.58
# total box: 2
# percentage of bounding box in total image : 10.14
# total box: 1
# percentage of bounding box in total image : 9.83
# total box: 1
# percentage of bounding box in total image : 13.61
# total box: 1
# percentage of bounding box in total image : 14.14
# total box: 2
# percentage of bounding box in total image : 8.62
# total box: 1
# percentage of bounding box in total image : 10.97
# total box: 1
# percentage of bounding box in total image : 11.71
# total box: 1
# percentage of bounding box in total image : 16.23
# total box: 1
# percentage of bounding box in total image : 13.50
# total box: 1
# percentage of bounding box in total image : 15.79
# total box: 1
# percentage of bounding box in total image : 9.97
# total box: 1
# percentage of bounding box in total image : 13.07
# total box: 1
# percentage of bounding box in total image : 10.73
# total box: 1
# percentage of bounding box in total image : 8.97
# total box: 1
# percentage of bounding box in total image : 13.11
# total box: 1
# percentage of bounding box in total image : 12.94
# total box: 1
# percentage of bounding box in total image : 10.88
# total box: 1
# percentage of bounding box in total image : 16.49
# total box: 1
# percentage of bounding box in total image : 20.50
# total box: 1
# percentage of bounding box in total image : 15.12
# total box: 1
# percentage of bounding box in total image : 16.43
# total box: 1
# percentage of bounding box in total image : 9.06
# total box: 1
# percentage of bounding box in total image : 20.75
# total box: 2
# percentage of bounding box in total image : 8.27
# total box: 1
# percentage of bounding box in total image : 12.17
# total box: 1
# percentage of bounding box in total image : 15.06
# total box: 1
# percentage of bounding box in total image : 12.13
# total box: 1
# percentage of bounding box in total image : 16.66
# total box: 1
# percentage of bounding box in total image : 12.98
# total box: 1
# percentage of bounding box in total image : 12.55
# total box: 1
# percentage of bounding box in total image : 12.56
# total box: 1
# percentage of bounding box in total image : 10.26
# total box: 1
# percentage of bounding box in total image : 13.51
# total box: 1
# percentage of bounding box in total image : 12.47
# total box: 1
# percentage of bounding box in total image : 9.45
# total box: 3
# percentage of bounding box in total image : 16.71
# percentage of bounding box in total image : 11.34
# total box: 1
# percentage of bounding box in total image : 12.67
# total box: 1
# percentage of bounding box in total image : 14.48
# total box: 2
# percentage of bounding box in total image : 9.43
# total box: 1
# percentage of bounding box in total image : 15.75
# total box: 1
# percentage of bounding box in total image : 8.79
# total box: 1
# percentage of bounding box in total image : 15.66
# total box: 1
# percentage of bounding box in total image : 11.74
# total box: 1
# percentage of bounding box in total image : 15.00
# total box: 1
# percentage of bounding box in total image : 12.95
# total box: 1
# percentage of bounding box in total image : 10.85
# total box: 2
# percentage of bounding box in total image : 14.78
# total box: 1
# percentage of bounding box in total image : 18.44
# total box: 1
# percentage of bounding box in total image : 18.91
# total box: 1
# percentage of bounding box in total image : 11.50
# total box: 2
# percentage of bounding box in total image : 14.42
# total box: 2
# percentage of bounding box in total image : 12.56
# total box: 1
# percentage of bounding box in total image : 13.55
# total box: 1
# percentage of bounding box in total image : 10.22
# total box: 1
# percentage of bounding box in total image : 13.94
# total box: 1
# percentage of bounding box in total image : 12.68
# total box: 2
# percentage of bounding box in total image : 8.07
# total box: 1
# percentage of bounding box in total image : 10.37
# total box: 1
# percentage of bounding box in total image : 13.90
# total box: 1
# percentage of bounding box in total image : 12.32
# total box: 1
# percentage of bounding box in total image : 9.00
# total box: 1
# percentage of bounding box in total image : 20.05
# total box: 1
# percentage of bounding box in total image : 20.02
# total box: 1
# percentage of bounding box in total image : 14.58
# total box: 1
# percentage of bounding box in total image : 14.19
# total box: 1
# percentage of bounding box in total image : 15.79
# total box: 2
# percentage of bounding box in total image : 13.03
# total box: 1
# percentage of bounding box in total image : 13.55
# total box: 1
# percentage of bounding box in total image : 10.08
# total box: 1
# percentage of bounding box in total image : 8.02
# total box: 1
# percentage of bounding box in total image : 10.80
# total box: 1
# percentage of bounding box in total image : 11.96
# total box: 1
# percentage of bounding box in total image : 11.77
# total box: 1
# percentage of bounding box in total image : 13.77
# total box: 1
# percentage of bounding box in total image : 9.23
# total box: 1
# percentage of bounding box in total image : 14.28
# total box: 1
# percentage of bounding box in total image : 11.38
# total box: 1
# percentage of bounding box in total image : 13.51
# total box: 1
# percentage of bounding box in total image : 9.77
# total box: 1
# percentage of bounding box in total image : 12.37
# total box: 1
# percentage of bounding box in total image : 15.98
# total box: 1
# percentage of bounding box in total image : 15.79
# total box: 1
# percentage of bounding box in total image : 8.31
# total box: 1
# percentage of bounding box in total image : 14.46
# total box: 1
# percentage of bounding box in total image : 10.20
# total box: 1
# percentage of bounding box in total image : 6.08
# total box: 1
# percentage of bounding box in total image : 11.28
# total box: 1
# percentage of bounding box in total image : 12.20
# total box: 1
# percentage of bounding box in total image : 11.05
# total box: 1
# percentage of bounding box in total image : 9.78
# total box: 2
# percentage of bounding box in total image : 8.58
# total box: 2
# percentage of bounding box in total image : 11.22
# total box: 1
# percentage of bounding box in total image : 14.62
# total box: 2
# percentage of bounding box in total image : 14.34
# total box: 1
# percentage of bounding box in total image : 9.42
# total box: 1
# percentage of bounding box in total image : 11.92
# total box: 2
# percentage of bounding box in total image : 9.90
# total box: 1
# percentage of bounding box in total image : 13.62
# total box: 1
# percentage of bounding box in total image : 11.65
# total box: 1
# percentage of bounding box in total image : 8.85
# total box: 1
# percentage of bounding box in total image : 7.30
# total box: 1
# percentage of bounding box in total image : 18.25
# total box: 1
# percentage of bounding box in total image : 10.72
# total box: 1
# percentage of bounding box in total image : 8.02
# total box: 1
# percentage of bounding box in total image : 13.49
# total box: 1
# percentage of bounding box in total image : 12.93
# total box: 1
# percentage of bounding box in total image : 9.77
# total box: 1
# percentage of bounding box in total image : 12.75
# total box: 1
# percentage of bounding box in total image : 17.00
# total box: 1
# percentage of bounding box in total image : 12.09
# total box: 1
# percentage of bounding box in total image : 16.89
# total box: 2
# percentage of bounding box in total image : 17.13
# total box: 1
# percentage of bounding box in total image : 16.80
# total box: 2
# percentage of bounding box in total image : 20.29
# total box: 2
# percentage of bounding box in total image : 14.66
# total box: 1
# percentage of bounding box in total image : 9.58
# total box: 1
# percentage of bounding box in total image : 14.68
# total box: 1
# percentage of bounding box in total image : 7.57
# total box: 1
# percentage of bounding box in total image : 14.43
# total box: 1
# percentage of bounding box in total image : 11.46
# total box: 1
# percentage of bounding box in total image : 13.85
# total box: 1
# percentage of bounding box in total image : 13.07
# total box: 1
# percentage of bounding box in total image : 9.30
# total box: 1
# percentage of bounding box in total image : 17.70
# total box: 1
# percentage of bounding box in total image : 19.16
# total box: 1
# percentage of bounding box in total image : 8.86
# total box: 1
# percentage of bounding box in total image : 11.90
# total box: 1
# percentage of bounding box in total image : 9.35
# total box: 1
# percentage of bounding box in total image : 12.26
# total box: 1
# percentage of bounding box in total image : 12.49
# total box: 1
# percentage of bounding box in total image : 17.74
# total box: 1
# percentage of bounding box in total image : 20.09
# total box: 1
# percentage of bounding box in total image : 9.95
# total box: 1
# percentage of bounding box in total image : 9.91
# total box: 1
# percentage of bounding box in total image : 11.93
# total box: 1
# percentage of bounding box in total image : 13.19
# total box: 1
# percentage of bounding box in total image : 14.25
# total box: 1
# percentage of bounding box in total image : 8.45
# total box: 1
# percentage of bounding box in total image : 10.13
# total box: 1
# percentage of bounding box in total image : 8.20
# total box: 1
# percentage of bounding box in total image : 10.86
# total box: 1
# percentage of bounding box in total image : 15.25
# total box: 1
# percentage of bounding box in total image : 7.45
# total box: 1
# percentage of bounding box in total image : 17.88
# total box: 1
# percentage of bounding box in total image : 9.77
# total box: 1
# percentage of bounding box in total image : 18.39
# total box: 1
# percentage of bounding box in total image : 12.27
# total box: 1
# percentage of bounding box in total image : 15.92
# total box: 1
# percentage of bounding box in total image : 14.17
# total box: 1
# percentage of bounding box in total image : 10.87
# total box: 1
# percentage of bounding box in total image : 15.34
# total box: 1
# percentage of bounding box in total image : 9.91
# total box: 1
# percentage of bounding box in total image : 14.23
# total box: 1
# percentage of bounding box in total image : 8.87
# total box: 1
# percentage of bounding box in total image : 14.24
# total box: 1
# percentage of bounding box in total image : 15.02
# total box: 1
# percentage of bounding box in total image : 16.18
# total box: 1
# percentage of bounding box in total image : 15.29
# total box: 1
# percentage of bounding box in total image : 18.28
# total box: 1
# percentage of bounding box in total image : 14.17
# total box: 1
# percentage of bounding box in total image : 8.26
# total box: 1
# percentage of bounding box in total image : 15.29
# total box: 1
# percentage of bounding box in total image : 8.05
# total box: 1
# percentage of bounding box in total image : 15.00
# total box: 1
# percentage of bounding box in total image : 12.45
# total box: 1
# percentage of bounding box in total image : 11.72
# total box: 1
# percentage of bounding box in total image : 20.86
# total box: 1
# percentage of bounding box in total image : 9.80
# total box: 1
# percentage of bounding box in total image : 8.76
# total box: 1
# percentage of bounding box in total image : 17.19
# total box: 1
# percentage of bounding box in total image : 12.43
# total box: 2
# percentage of bounding box in total image : 16.99
# total box: 1
# percentage of bounding box in total image : 19.95
# total box: 1
# percentage of bounding box in total image : 11.74
# total box: 1
# percentage of bounding box in total image : 20.77
# total box: 1
# percentage of bounding box in total image : 14.35
# total box: 2
# percentage of bounding box in total image : 15.88
# total box: 1
# percentage of bounding box in total image : 17.00
# total box: 1
# percentage of bounding box in total image : 11.27
# total box: 1
# percentage of bounding box in total image : 11.69
# total box: 1
# percentage of bounding box in total image : 9.69
# total box: 2
# percentage of bounding box in total image : 10.28
# total box: 1
# percentage of bounding box in total image : 11.08
# total box: 1
# percentage of bounding box in total image : 10.12
# total box: 1
# percentage of bounding box in total image : 16.60
# total box: 2
# percentage of bounding box in total image : 15.06
# total box: 1
# percentage of bounding box in total image : 9.73
# total box: 1
# percentage of bounding box in total image : 8.75
# total box: 1
# percentage of bounding box in total image : 15.48
# total box: 1
# percentage of bounding box in total image : 10.79
# total box: 1
# percentage of bounding box in total image : 8.12
# total box: 1
# percentage of bounding box in total image : 17.37
# total box: 1
# percentage of bounding box in total image : 8.08
# total box: 1
# percentage of bounding box in total image : 16.79
# total box: 1
# percentage of bounding box in total image : 13.78
# total box: 1
# percentage of bounding box in total image : 17.06
# total box: 1
# percentage of bounding box in total image : 14.84
# total box: 1
# percentage of bounding box in total image : 9.08
# total box: 1
# percentage of bounding box in total image : 15.37
# total box: 1
# percentage of bounding box in total image : 11.28
# total box: 1
# percentage of bounding box in total image : 7.85
# total box: 1
# percentage of bounding box in total image : 10.77

# %%
def sample(x):
    class A:
        def __init__(self, x):
            self.x = x
        def square(self, x):
            return x*x
print(sample(A.square(4)))
